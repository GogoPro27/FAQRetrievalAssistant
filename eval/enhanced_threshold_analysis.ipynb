# %% [markdown]
# # Confidence Threshold Analysis (Enhanced Retrieval)
#
# This notebook determines an appropriate confidence threshold for the FAQ
# retrieval system using **enhanced evaluation results** after multilingual
# question augmentation.
#
# The goal is to balance:
# - **Accuracy**: correctness when answering confidently
# - **Coverage**: how often the system provides a confident answer
#
# The chosen threshold will be applied in the application to trigger
# a fallback UX when confidence is low, ensuring reliable behavior
# across both English and Macedonian queries.

# %%
import pandas as pd
import numpy as np

# %%
RESULTS_PATH = "results/enhanced_results.csv"

df = pd.read_csv(RESULTS_PATH)
df
# Out:
#                                                 query language  \
# 0   I can't log into my account, how do I reset my...       en
# 1           Forgot my password and now I'm locked out       en
# 2              The password reset email never arrives       en
# 3    How can I update the email linked to my account?       en
# 4          Where can I change my credit card details?       en
# 5                My card was charged twice this month       en
# 6                      I want to stop my subscription       en
# 7      If I cancel my plan, will I get my money back?       en
# 8                How do I download previous invoices?       en
# 9                Which credit cards can I use to pay?       en
# 10                           How can I reach support?       en
# 11                When is customer support available?       en
# 12            I want to permanently delete my account       en
# 13        Can I recover my account after deleting it?       en
# 14       My account was disabled and I don't know why       en
# 15       How do I move to a higher subscription plan?       en
# 16  Is my personal information safe on your platform?       en
# 17       Does the app support more than one language?       en
# 18     I found a bug in the app, how can I report it?       en
# 19     Why does the application take so long to load?       en
# 20     Не можам да се најавам, ја заборавив лозинката       mk
# 21       Не ми стигнува мејл за ресетирање на лозинка       mk
# 22      Како да ја сменам емаил адресата на профилот?       mk
# 23   Каде можам да ги ажурирам податоците за плаќање?       mk
# 24         Ми беше наплатено двапати со иста картичка       mk
# 25                    Сакам да ја откажам претплатата       mk
# 26   Ќе добијам ли поврат ако ја откажам претплатата?       mk
# 27                       Како да ги симнам фактурите?       mk
# 28             Како да стапам во контакт со поддршка?       mk
# 29         Во кое време работи корисничката поддршка?       mk
# 30           Сакам трајно да го избришам мојот профил       mk
# 31                 Апликацијата ми работи многу бавно       mk
#
#                       expected_faq_id  \
# 0                 reset_password_q_en
# 1          forgot_password_login_q_en
# 2   password_reset_email_missing_q_en
# 3                   change_email_q_en
# 4                 update_billing_q_en
# 5                  double_charge_q_en
# 6            cancel_subscription_q_en
# 7                  refund_policy_q_en
# 8              download_invoices_q_en
# 9                payment_methods_q_en
# 10               contact_support_q_en
# 11                 support_hours_q_en
# 12                delete_account_q_en
# 13            reactivate_account_q_en
# 14             account_suspended_q_en
# 15          upgrade_subscription_q_en
# 16                 data_security_q_en
# 17              language_support_q_en
# 18                    report_bug_q_en
# 19            performance_issues_q_en
# 20                reset_password_q_en
# 21                reset_password_q_en
# 22                  change_email_q_en
# 23                update_billing_q_en
# 24                 double_charge_q_en
# 25           cancel_subscription_q_en
# 26                 refund_policy_q_en
# 27             download_invoices_q_en
# 28               contact_support_q_en
# 29                 support_hours_q_en
# 30                delete_account_q_en
# 31            performance_issues_q_en
#
#                                         retrieved_ids  rank_of_expected  \
# 0   ['reset_password_q_en', 'forgot_password_login...                 1
# 1   ['forgot_password_login_q_en', 'reset_password...                 1
# 2   ['password_reset_email_missing_q_en', 'reset_p...                 1
# 3   ['change_email_q_en', 'update_billing_q_en', '...                 1
# 4   ['change_email_q_en', 'update_billing_q_en', '...                 2
# 5   ['double_charge_q_en', 'update_billing_q_en', ...                 1
# 6   ['cancel_subscription_q_en', 'upgrade_subscrip...                 1
# 7   ['refund_policy_q_en', 'cancel_subscription_q_...                 1
# 8   ['download_invoices_q_en', 'update_billing_q_e...                 1
# 9   ['payment_methods_q_en', 'update_billing_q_en'...                 1
# 10  ['contact_support_q_en', 'support_hours_q_en',...                 1
# 11  ['support_hours_q_en', 'contact_support_q_en',...                 1
# 12  ['delete_account_q_en', 'reactivate_account_q_...                 1
# 13  ['reactivate_account_q_en', 'delete_account_q_...                 1
# 14  ['account_suspended_q_en', 'reactivate_account...                 1
# 15  ['upgrade_subscription_q_en', 'cancel_subscrip...                 1
# 16  ['data_security_q_en', 'account_suspended_q_en...                 1
# 17  ['language_support_q_en', 'performance_issues_...                 1
# 18  ['report_bug_q_en', 'contact_support_q_en', 'u...                 1
# 19  ['performance_issues_q_en', 'support_hours_q_e...                 1
# 20  ['forgot_password_login_q_en', 'password_reset...                 3
# 21  ['password_reset_email_missing_q_en', 'reset_p...                 2
# 22  ['change_email_q_en', 'delete_account_q_en', '...                 1
# 23  ['update_billing_q_en', 'payment_methods_q_en'...                 1
# 24  ['double_charge_q_en', 'upgrade_subscription_q...                 1
# 25  ['cancel_subscription_q_en', 'refund_policy_q_...                 1
# 26  ['refund_policy_q_en', 'cancel_subscription_q_...                 1
# 27  ['download_invoices_q_en', 'report_bug_q_en', ...                 1
# 28  ['contact_support_q_en', 'support_hours_q_en',...                 1
# 29  ['support_hours_q_en', 'contact_support_q_en',...                 1
# 30  ['delete_account_q_en', 'account_suspended_q_e...                 1
# 31  ['performance_issues_q_en', 'support_hours_q_e...                 1
#
#     top1_correct  top3_correct  confidence
# 0           True          True       0.681
# 1           True          True       0.648
# 2           True          True       0.590
# 3           True          True       0.485
# 4          False          True       0.151
# 5           True          True       0.752
# 6           True          True       0.708
# 7           True          True       0.659
# 8           True          True       0.807
# 9           True          True       0.413
# 10          True          True       0.648
# 11          True          True       0.703
# 12          True          True       0.632
# 13          True          True       0.693
# 14          True          True       0.546
# 15          True          True       0.767
# 16          True          True       0.676
# 17          True          True       0.679
# 18          True          True       0.683
# 19          True          True       0.714
# 20         False          True       0.810
# 21         False          True       0.790
# 22          True          True       0.870
# 23          True          True       0.809
# 24          True          True       0.808
# 25          True          True       0.474
# 26          True          True       1.000
# 27          True          True       1.000
# 28          True          True       0.633
# 29          True          True       0.862
# 30          True          True       0.540
# 31          True          True       0.710

# %%
df.groupby("top1_correct")["confidence"].describe()
# Out:
#               count      mean       std    min     25%    50%    75%   max
# top1_correct
# False           3.0  0.583667  0.374834  0.151  0.4705  0.790  0.800  0.81
# True           29.0  0.696207  0.138395  0.413  0.6330  0.683  0.767  1.00

# %%
thresholds = np.arange(0.15, 0.81, 0.05)
thresholds
# Out:
# array([0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 , 0.55, 0.6 , 0.65,
#        0.7 , 0.75, 0.8 ])

# %%
rows = []

for t in thresholds:
    covered = df[df["confidence"] >= t]

    coverage = len(covered) / len(df)

    if len(covered) > 0:
        accuracy = covered["top1_correct"].mean()
    else:
        accuracy = np.nan

    rows.append({
        "threshold": round(float(t), 2),
        "coverage": round(float(coverage), 3),
        "accuracy": round(float(accuracy), 3) if not np.isnan(accuracy) else None,
        "num_covered": len(covered)
    })

threshold_df = pd.DataFrame(rows)
threshold_df
# Out:
#     threshold  coverage  accuracy  num_covered
# 0        0.15     1.000     0.906           32
# 1        0.20     0.969     0.935           31
# 2        0.25     0.969     0.935           31
# 3        0.30     0.969     0.935           31
# 4        0.35     0.969     0.935           31
# 5        0.40     0.969     0.935           31
# 6        0.45     0.938     0.933           30
# 7        0.50     0.875     0.929           28
# 8        0.55     0.812     0.923           26
# 9        0.60     0.781     0.920           25
# 10       0.65     0.656     0.905           21
# 11       0.70     0.469     0.867           15
# 12       0.75     0.344     0.818           11
# 13       0.80     0.250     0.875            8

# %%
threshold_df.plot(
    x="threshold",
    y=["coverage", "accuracy"],
    marker="o",
    title="Accuracy vs Coverage by Confidence Threshold"
)
# Out:
# <Axes: title={'center': 'Accuracy vs Coverage by Confidence Threshold'}, xlabel='threshold'>

# %%
lang_rows = []

for t in thresholds:
    for lang in ["en", "mk"]:
        subset = df[(df["confidence"] >= t) & (df["language"] == lang)]

        coverage = len(subset) / len(df[df["language"] == lang])
        accuracy = subset["top1_correct"].mean() if len(subset) > 0 else None

        lang_rows.append({
            "threshold": round(float(t), 2),
            "language": lang,
            "coverage": round(float(coverage), 3),
            "accuracy": round(float(accuracy), 3) if accuracy is not None else None
        })

lang_threshold_df = pd.DataFrame(lang_rows)
lang_threshold_df
# Out:
#     threshold language  coverage  accuracy
# 0        0.15       en     1.000     0.950
# 1        0.15       mk     1.000     0.833
# 2        0.20       en     0.950     1.000
# 3        0.20       mk     1.000     0.833
# 4        0.25       en     0.950     1.000
# 5        0.25       mk     1.000     0.833
# 6        0.30       en     0.950     1.000
# 7        0.30       mk     1.000     0.833
# 8        0.35       en     0.950     1.000
# 9        0.35       mk     1.000     0.833
# 10       0.40       en     0.950     1.000
# 11       0.40       mk     1.000     0.833
# 12       0.45       en     0.900     1.000
# 13       0.45       mk     1.000     0.833
# 14       0.50       en     0.850     1.000
# 15       0.50       mk     0.917     0.818
# 16       0.55       en     0.800     1.000
# 17       0.55       mk     0.833     0.800
# 18       0.60       en     0.750     1.000
# 19       0.60       mk     0.833     0.800
# 20       0.65       en     0.600     1.000
# 21       0.65       mk     0.750     0.778
# 22       0.70       en     0.300     1.000
# 23       0.70       mk     0.750     0.778
# 24       0.75       en     0.150     1.000
# 25       0.75       mk     0.667     0.750
# 26       0.80       en     0.050     1.000
# 27       0.80       mk     0.583     0.857

# %% [markdown]
# ## Threshold Selection
#
# Based on the accuracy–coverage tradeoff observed in the enhanced evaluation, threshold **0.65** achieves a strong balance between accuracy and coverage
#
# At this threshold:
# - Accuracy remains above **90%**
# - Coverage remains acceptable for user experience
# - Confidence filtering is stricter than baseline without being overly aggressive
#
# **Chosen threshold: 0.7**
